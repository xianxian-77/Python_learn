# %% [markdown]
# # Assignment 1
#
# In this two part assignment you will first use Python to load, clean, and analyse a simple dataset to answer set questions, and then in part two, you will use these skills in an open-ended exploration of a larger, more complex real world dataset from the Edinburgh International Book Festival.
#
# You will be assessed by how well your work demonstrates the following learning objectives:
#
# LO1: Identify, understand and deploy programming strategies for working with data in multiple formats using Python
#
# LO2: Demonstrate the ability to transform, combine, analyse, learn from and creatively explore a range of data in ways that are relevant to particular contexts of enquiry

# %% [markdown]
# ## Part 1: Basic Exploratory Data Analysis

# %% [markdown]
# ### Step 1: Loading the Data
#
# Load the data from the supplied file `restaurant_data.csv`

# %% [markdown]
# ### Step 2: Cleaning the data
#
# ##### A. The data had some some strange things in it. Write down all of the strange things that you found here:

# %% [markdown]
# [[[[EDIT THIS TEXT BLOCK]]]]
#
# * Strange thing 1: [enter the first strange thing you noticed]
# * Enter more strange things ....

# %% [markdown]
# #### B. Now, clean the data. Use the text cell to explain what you are doing and _why_ and the code cell to do the cleaning, providing appropriate code comments.

# %% [markdown]
# [[[[EDIT THIS TEXT BLOCK: What are you removing or changing from the data and why]]]]

# %%
# Cleaning code goes in here

# %% [markdown]
# ### Step 3: Describing the Data with Statistics
# ##### For each of the following questions, we want a command that just prints the relevant answer. The first one has been filled out as an example

# %% [markdown]
# How many rows are in the dataset after cleaning?

# %%
data.shape[0] # Simply count the number of rows using shape, and select the first element

# %% [markdown]
# What is the total amount of tips given?

# %% [markdown]
# What is the largest group?

# %% [markdown]
# How many bills were paid by males, and how many by females?

# %% [markdown]
# What is the average percentage of the bill that people add as a tip?

# %% [markdown]
# What is the largest tip?

# %% [markdown]
# What day of the week was the largest tip given on?

# %% [markdown]
# Do males or females give more tips as an average of the bill? What is the difference?

# %% [markdown]
# Do smokers tip more at lunchtime than at dinnertime?

# %% [markdown]
# ### Step 4: Visualising the Data
# ##### For all the following questions, use a GRAPH to illustrate your answer

# %% [markdown]
# What is the distribution of tips? Hint: histplot

# %% [markdown]
# What is the distribution of total bills?

# %% [markdown]
# How does the size of the tip relate to the size of the bill? Hint: scatterplot, lmplot

# %% [markdown]
# Does the proportion of the bill given as a tip relate to the number of people eating?

# %% [markdown]
# ## Part 2: Exploring a real world dataset
# Use the same steps as above to explore the Edinburgh International Book Festival Data included in the zip file for this assignment (**Note: While this dataset comes from the Festivals and Travel datasets, it will not be eligible for use in your final project**).
#
# We want to see that you can load the data (potentially from multiple files), clean it if necessary, perform statistics, and visualise it in a way the provides insights into the data. For example, do you see any trends or patterns in the ticket transactions, such as types of events, time purchased, events purchased by the same customers, where the customers are from, etc.? Why might these patterns occur? How might the Book Festival use this data? We want to see both your technical ability to work with the data and also your ability to think critically and creatively about it.

# %% [markdown]
# Use the following template to carry out your investigation

# %% [markdown]
# ## Introduction

# %% [markdown]
# [[[[[ **REPLACE THIS TEXT BLOCK** to introduce and **DESCRIBE** the dataset. For example, what does the data represent, what types of data does it contain, what assumptions are made in the data, what data might be missing, and any other information you think is important ]]]]]

# %% [markdown]
# ## Method

# %% [markdown]
# [[[[[ **REPLACE THIS TEXT BLOCK** to describe how you will **EXPLORE** the data in this assignment: Does it need cleaning or preprocessing? Will you combine data from different csv files and why? What statistics will you run on it? How will you visualise it and why? ]]]]]

# %% [markdown]
# ##### Use the markdown and python cells below to carry out the exploration and explain what you are doing and why. Use the first text block to describe what you will do in the code block, add your code in the code block and run it, and then use the text block after the code to make observations and comments. **ADD ADDITIONAL ONES AS NEEDED TO CARRY OUT YOUR EXPLORATION**

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to explain what you are going to do in the next code block and why ]]]]

# %%
#Use this code block to do something with your data, using comments to explain what your code is doing

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to make observations or comment on the results of the code above ]]]]

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to explain what you are going to do in the next code block and why ]]]]

# %%
#Use this code block to do something with your data, using comments to explain what your code is doing

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to make observations or comment on the results of the code above ]]]]

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to explain what you are going to do in the next code block and why ]]]]

# %%
#Use this code block to do something with your data, using comments to explain what your code is doing

# %% [markdown]
# [[[[ **REPLACE THIS TEXT BLOCK** to make observations or comment on the results of the code above ]]]]

# %% [markdown]
# ## Discussion

# %% [markdown]
# [[[[[ **REPLACE THIS TEXT BLOCK** to **REFLECT** on the data and your exploration: What discoveries did you make? Why are they important or meaningful? Do they suggest something about the data or the subject of the data? What hypotheses can you form from the data for further exploration? ]]]]]

# %% [markdown]
# ## Use of AI

# %% [markdown]
# Academic integrity is an underlying principle of research and academic practice. All submitted work is expected to be your own and will be assessed on the basis of your creativity, programming skills and critical thinking. You should not paste code or text generated by AI directly into your assignments in DS4D as this does not demonstrate your own learning. However, you are allowed to use these tools to experiment, generate ideas, assist in translation or debugging, and improve the clarity of your writing. If you use AI software, you must acknowledge and discuss its use below. Please consult [University Guidance on the Use of Generative AI](https://bayes-centre.ed.ac.uk/ai-guidance-for-staff-and-students/ai-guidance-for-students) for more details.

# %% [markdown]
# NOTE: You should NOT have needed to use AI code generation in Part 1 of this assignment

# %% [markdown]
# [[[[[ **REPLACE THIS TEXT BLOCK** to describe any ways in which you used AI tools in this assignment, for example, text or code generation, translation, ideation, etc. What prompts did you use? How did you assess the quality of the results? How did you edit or incorporate the results into this assignment? How did you apply your own creativity, programming skills and critical thinking in addition to using these tools? ]]]]]
